# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
MasterData = pd.read_csv("C:/Users/kobalaji/Desktop/LetsUpgrade AI-ML/Day 07/general_data.csv")

# %%
MasterData.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
MasterData.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
MasterData.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
MasterData.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
Attrition_Yes =MasterData[MasterData['Attrition']=="Yes"]

# %%
Attrition_Yes
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4381   29       Yes      Travel_Rarely  Research & Development
# 4386   33       Yes      Travel_Rarely                   Sales
# 4388   33       Yes      Travel_Rarely                   Sales
# 4391   32       Yes      Travel_Rarely                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                   10          1  Life Sciences              1           2
# ...

# %%
Attrition_No =MasterData[MasterData['Attrition']=="No"]

# %%
Attrition_No
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
Attrition_Yes.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
Attrition_Yes['MonthlyIncome'].describe()
# Out:
# count       711.000000
# mean      61682.616034
# std       44792.067695
# min       10090.000000
# 25%       28440.000000
# 50%       49080.000000
# 75%       71040.000000
# max      198590.000000
# Name: MonthlyIncome, dtype: float64

# %%
Attrition_Yes.describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  711.000000        711.000000  711.000000          711.0   711.000000
# mean    33.607595          9.012658    2.877637            1.0  2191.767932
# std      9.675693          7.772368    1.014233            0.0  1270.136654
# min     18.000000          1.000000    1.000000            1.0     2.000000
# 25%     28.000000          2.000000    2.000000            1.0  1072.000000
# 50%     32.000000          7.000000    3.000000            1.0  2165.000000
# 75%     39.000000         15.000000    4.000000            1.0  3341.000000
# max     58.000000         29.000000    5.000000            1.0  4403.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  711.000000     711.000000          707.000000         711.000000
# mean     2.037975   61682.616034            2.936351          15.481013
# ...

# %% [markdown]
# # Hypothesis Testing
#
# Null Hypothesis is Age <=30
# Alternative Hypothesis is Age >30
#
# Null Hypothesis is Monthly income <=35000
# Alternative Hypothesis is Age >35000
#
# Null Hypothesis is YearsWithCurrManager >=3
# Alternative Hypothesis is YearsWithCurrManager <3

# %% [markdown]
# # 1 -  Hypothesis Testing
# Null Hypothesis is Age <=30
# Alternative Hypothesis is Age >30

# %%
Age_30 = Attrition_Yes[Attrition_Yes['Age']<=30]

# %%
Age_30['Age'].describe()
# Out:
# count    300.000000
# mean      25.290000
# std        3.721837
# min       18.000000
# 25%       22.000000
# 50%       26.000000
# 75%       29.000000
# max       30.000000
# Name: Age, dtype: float64

# %%
Sample_Data= Attrition_Yes.sample(30)

# %%
Age_30['Age'].skew()
# Out:
# -0.4875617502234611

# %%
Age_30['Age'].kurtosis()
# Out:
# -1.0692730497659366

# %%
plt.boxplot(Age_30.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a61b210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ba397f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a61b5f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ba39f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ba39970>],
#  'means': []}

# %%
plt.hist(Age_30.Age)
# Out:
# (array([30., 18., 18., 15., 12., 39., 36.,  9., 42., 81.]),
#  array([18. , 19.2, 20.4, 21.6, 22.8, 24. , 25.2, 26.4, 27.6, 28.8, 30. ]),
#  <a list of 10 Patch objects>)

# %%
Pop_Mean= Age_30['Age'].mean()
Pop_Median= Age_30['Age'].median()
Pop_Std= Age_30['Age'].std()

# %%
print('Mean:',Pop_Mean,'\nMedian:',Pop_Median,'\nStd:',Pop_Std)
# Out:
# Mean: 25.29
# Median: 26.0
# Std: 3.721837392820288

# %%
Samp_Mean= Sample_Data['Age'].mean()
Samp_Median= Sample_Data['Age'].median()
Samp_Std= Sample_Data['Age'].std()

# %%
print('Mean:',Samp_Mean,'\nMedian:',Samp_Median,'\nStd:',Samp_Std)
# Out:
# Mean: 30.1
# Median: 29.5
# Std: 8.774374916335281

# %%
x = np.sqrt(Sample_Data['Age'].count())
x
# Out:
# 5.477225575051661

# %%
Z_Test = (Samp_Mean - Pop_Mean)/(Pop_Std/np.sqrt(Sample_Data['Age'].count()))

# %%
T_Test= (Samp_Mean - Pop_Mean)/(Samp_Std/np.sqrt(Sample_Data['Age'].count()))
T_Test
# Out:
# 3.0833379600009807

# %%
Z_Test
# Out:
# 7.078615273956063

# %%
Alpha = 0.05
DoF = Sample_Data['Age'].count()-1
Z_Score = 1.645
T_Score = 1.697

# %%
DoF
# Out:
# 29

# %% [markdown]
# # As per the Z_Score is 1.645  and Z_test is 7.07 so we have evidence that less than 30 year are leaving the company
#
# # Krutosis is platykurtic.

# %% [markdown]
# # 2 -  Hypothesis Testing
#
# Null Hypothesis is Monthly income <=40000
# Alternative Hypothesis is Age >40000

# %%
 Monthlyincome_40000 = Attrition_Yes[Attrition_Yes['MonthlyIncome']<=40000]

# %%
Monthlyincome_40000['MonthlyIncome'].describe()
# Out:
# count      270.000000
# mean     26536.888889
# std       6108.329795
# min      10090.000000
# 25%      22740.000000
# 50%      26335.000000
# 75%      29760.000000
# max      40000.000000
# Name: MonthlyIncome, dtype: float64

# %%
Sample_MonthlyIncome  = Attrition_Yes.sample(30)

# %%
Sample_MonthlyIncome['MonthlyIncome'].describe()
# Out:
# count        30.000000
# mean      50641.000000
# std       42818.418076
# min       11290.000000
# 25%       23417.500000
# 50%       32040.000000
# 75%       60870.000000
# max      191900.000000
# Name: MonthlyIncome, dtype: float64

# %%
Monthlyincome_40000['MonthlyIncome'].skew()
# Out:
# -0.038408868289558605

# %%
Monthlyincome_40000['MonthlyIncome'].kurtosis()
# Out:
# 0.04753277993829963

# %%
plt.boxplot(Monthlyincome_40000.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a73d170>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c06b510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a73d070>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ba74b30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ba74230>],
#  'means': []}

# %%
plt.hist(Monthlyincome_35000.MonthlyIncome)
# Out:
# (array([ 6.,  9.,  9., 33., 51., 63., 42., 15., 33.,  9.]),
#  array([10090., 13081., 16072., 19063., 22054., 25045., 28036., 31027.,
#         34018., 37009., 40000.]),
#  <a list of 10 Patch objects>)

# %%
Pop_Mean= Monthlyincome_40000['MonthlyIncome'].mean()
Pop_Median= Monthlyincome_40000['MonthlyIncome'].median()
Pop_Std= Monthlyincome_40000['MonthlyIncome'].std()
print('Mean:',Pop_Mean,'\nMedian:',Pop_Median,'\nStd:',Pop_Std)
# Out:
# Mean: 26536.88888888889
# Median: 26335.0
# Std: 6108.329795225261

# %%
Samp_Mean= Sample_MonthlyIncome['MonthlyIncome'].mean()
Samp_Median= Sample_MonthlyIncome['MonthlyIncome'].median()
Samp_Std= Sample_MonthlyIncome['MonthlyIncome'].std()
print('Mean:',Samp_Mean,'\nMedian:',Samp_Median,'\nStd:',Samp_Std)
# Out:
# Mean: 50641.0
# Median: 32040.0
# Std: 42818.41807624056

# %%
# Out:
# 30

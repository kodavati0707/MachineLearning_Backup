# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Linear Regression

# %%
LR_Data = pd.read_excel('C:/Users/kobalaji/Desktop/LetsUpgrade AI-ML/Day 21/dataset/Linear Regression.xlsx',sheet_name = 0)

# %%
LR_Data.head(10)
# Out:
#      price  sqft_living  bedrooms  bathrooms  floors
# 0   221900         1180         3       1.00     1.0
# 1   538000         2570         3       2.25     2.0
# 2   180000          770         2       1.00     1.0
# 3   604000         1960         4       3.00     1.0
# 4   510000         1680         3       2.00     1.0
# 5  1225000         5420         4       4.50     1.0
# 6   257500         1715         3       2.25     2.0
# 7   291850         1060         3       1.50     1.0
# 8   229500         1780         3       1.00     1.0
# 9   323000         1890         3       2.50     2.0

# %%
g = sns.pairplot(LR_Data, hue='floors')
# Out:
# c:\users\kobalaji\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x = LR_Data.bedrooms)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
sns.barplot(y = LR_Data.bedrooms, x =LR_Data.sqft_living)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='bedrooms'>

# %%
sns.scatterplot(x= LR_Data.sqft_living,y =LR_Data.price)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
LR_Data.hist(figsize=(15,10),bins= 10)
# Out:
# c:\users\kobalaji\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\kobalaji\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\kobalaji\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# ...

# %%
g = sns.pairplot(LR_Data, kind="reg")

# %%
ax = sns.boxplot(data=LR_Data)

# %%
plt.boxplot(LR_Data.floors)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16683190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x166835d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1668bf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x16683a10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16683bf0>],
#  'means': []}

# %%
plt.boxplot(LR_Data.sqft_living)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18445390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x184457d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18445170>],
#  'medians': [<matplotlib.lines.Line2D at 0x18445c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18445df0>],
#  'means': []}

# %%
LR_Data.describe()
# Out:
#               price   sqft_living      bedrooms     bathrooms        floors
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   5.400881e+05   2079.899736      3.370842      2.114757      1.494309
# std    3.671272e+05    918.440897      0.930062      0.770163      0.539989
# min    7.500000e+04    290.000000      0.000000      0.000000      1.000000
# 25%    3.219500e+05   1427.000000      3.000000      1.750000      1.000000
# 50%    4.500000e+05   1910.000000      3.000000      2.250000      1.500000
# 75%    6.450000e+05   2550.000000      4.000000      2.500000      2.000000
# max    7.700000e+06  13540.000000     33.000000      8.000000      3.500000

# %%
LR_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 5 columns):
# price          21613 non-null int64
# sqft_living    21613 non-null int64
# bedrooms       21613 non-null int64
# bathrooms      21613 non-null float64
# floors         21613 non-null float64
# dtypes: float64(2), int64(3)
# memory usage: 844.3 KB

# %%
LR_Data.isna().sum()
# Out:
# price          0
# sqft_living    0
# bedrooms       0
# bathrooms      0
# floors         0
# dtype: int64

# %%
LR_Data[LR_Data.sqft_living == 13540]
# Out:
#          price  sqft_living  bedrooms  bathrooms  floors
# 12777  2280000        13540         7        8.0     3.0

# %%
LR_Data[LR_Data.sqft_living == np.min(LR_Data.sqft_living)]
# Out:
#         price  sqft_living  bedrooms  bathrooms  floors
# 19452  142000          290         0        0.0     1.0

# %%
LR_Data.skew()
# Out:
# price          4.024069
# sqft_living    1.471555
# bedrooms       1.974300
# bathrooms      0.511108
# floors         0.616177
# dtype: float64

# %%
LR_Data.corr()
# Out:
#                 price  sqft_living  bedrooms  bathrooms    floors
# price        1.000000     0.702035  0.308350   0.525138  0.256794
# sqft_living  0.702035     1.000000  0.576671   0.754665  0.353949
# bedrooms     0.308350     0.576671  1.000000   0.515884  0.175429
# bathrooms    0.525138     0.754665  0.515884   1.000000  0.500653
# floors       0.256794     0.353949  0.175429   0.500653  1.000000

# %%
sns.heatmap(LR_Data.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
x = LR_Data.iloc[:,1:]

print(x.size)
x.drop('bedrooms',axis=1,inplace= True)
print(x)
# Out:
# 86452
#        sqft_living  bathrooms  floors
# 0             1180       1.00     1.0
# 1             2570       2.25     2.0
# 2              770       1.00     1.0
# 3             1960       3.00     1.0
# 4             1680       2.00     1.0
# ...            ...        ...     ...
# 21608         1530       2.50     3.0
# 21609         2310       2.50     2.0
# 21610         1020       0.75     2.0
# 21611         1600       2.50     2.0
# 21612         1020       0.75     2.0
#
# [21613 rows x 3 columns]

# %%
y = LR_Data.iloc[:,:1]
print(y.head(10))
print(y.size)
# Out:
#      price
# 0   221900
# 1   538000
# 2   180000
# 3   604000
# 4   510000
# 5  1225000
# 6   257500
# 7   291850
# 8   229500
# 9   323000
# 21613

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size =0.30,random_state = 2)

# %%
y_train
# Out:
#         price
# 17686  750000
# 1160   267500
# 4473   381000
# 7434   312500
# 7883   950000
# ...       ...
# 1099   151000
# 18898  325000
# 11798  905000
# 6637   313000
# 2575   690000
#
# [15129 rows x 1 columns]

# %%
y_train.size
# Out:
# 15129

# %%
x_train.count()
# Out:
# sqft_living    15129
# bathrooms      15129
# floors         15129
# dtype: int64

# %%
y_train.shape
# Out:
# (15129, 1)

# %%
x_train.shape
# Out:
# (15129, 3)

# %%
print(x_test,y_test)
# Out:
#        sqft_living  bathrooms  floors
# 6638          2410       2.25     1.5
# 7366          2170       1.50     1.0
# 3158          1450       1.00     1.0
# 9117          4500       3.25     2.0
# 3392           860       1.00     1.0
# ...            ...        ...     ...
# 11762         1550       1.50     1.0
# 15526         3160       2.50     2.0
# 9167          2370       2.50     2.0
# 17917         1350       2.25     2.0
# 11981         2120       1.75     1.5
#
# [6484 rows x 3 columns]          price
# 6638    735000
# 7366   1150000
# 3158    350500
# 9117    860000
# 3392    122000
# ...        ...
# 11762   350000
# 15526  1190000
# 9167    338000
# 17917   397500
# 11981   980000
#
# [6484 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
#lm.fit(x_train,y_train)
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Model_score =lm.score

# %%
print(Model_score)
# Out:
# <bound method RegressorMixin.score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>

# %%
lm.coef_
# Out:
# array([[  282.57780792, -6731.70763476,  8647.8449482 ]])

# %%
lm.intercept_
# Out:
# array([-44310.10352505])

# %%
Ypred = lm.predict(x_test)

# %%
Ypred
# Out:
# array([[634527.83881407],
#        [567434.02316446],
#        [367343.8552771 ],
#        ...,
#        [625865.72206255],
#        [339319.28488953],
#        [555946.12833371]])

# %%
x_test.columns
# Out:
# Index(['sqft_living', 'bathrooms', 'floors'], dtype='object')

# %%
cols = ['sqft_living', 'bedrooms', 'bathrooms']

# %%
df= pd.DataFrame(np.array(x_test),columns=cols)

# %%
df.head()
# Out:
#    sqft_living  bedrooms  bathrooms
# 0       2410.0      2.25        1.5
# 1       2170.0      1.50        1.0
# 2       1450.0      1.00        1.0
# 3       4500.0      3.25        2.0
# 4        860.0      1.00        1.0

# %%
df['Predicted'] = pd.DataFrame(Ypred)

# %%
df.head()
# Out:
#    sqft_living  bedrooms  bathrooms     Predicted
# 0       2410.0      2.25        1.5  6.345278e+05
# 1       2170.0      1.50        1.0  5.674340e+05
# 2       1450.0      1.00        1.0  3.673439e+05
# 3       4500.0      3.25        2.0  1.222708e+06
# 4        860.0      1.00        1.0  2.006229e+05

# %%
predicted = lm.predict(np.array([[2000,3,2]]))

# %%
predicted
# Out:
# array([[517946.07931357]])

# %%
lm.predict(np.array([[3000,4,3]]))
# Out:
# array([[802440.02455026]])

# %%
from sklearn.metrics import r2_score

# %%
R_score = r2_score(y_test,Ypred)

# %%
print(R_score)
# Out:
# 0.49555786554599757

# %%
X= LR_Data['sqft_living']
X.head()
# Out:
# 0    1180
# 1    2570
# 2     770
# 3    1960
# 4    1680
# Name: sqft_living, dtype: int64

# %%
Y = LR_Data['price']
Y.head()
# Out:
# 0    221900
# 1    538000
# 2    180000
# 3    604000
# 4    510000
# Name: price, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size =0.10,random_state =3)

# %%
print(X_train.size,X_train.shape)
# Out:
# 58353 (19451, 3)

# %%
X_train.head()
# Out:
#        sqft_living  bathrooms  floors
# 14323         1560       1.75     1.0
# 10300          750       1.00     1.0
# 16151         1230       1.75     1.0
# 6086           860       1.00     1.0
# 4577          1090       1.00     1.5

# %%
print(Y_train.size,Y_train.shape)
# Out:
# 19451 (19451, 1)

# %%
Y_train.head()
# Out:
#         price
# 14323  549010
# 10300  338000
# 16151  239950
# 6086   330000
# 4577   690000

# %%
lmr = LinearRegression()

# %%
lmr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lmr.coef_
# Out:
# array([[  286.65984551, -9937.34369491,  7970.34222499]])

# %%
lmr.intercept_
# Out:
# array([-47392.74628401])

# %%
y_Pred = lmr.predict(X_test)

# %%
y_Pred
# Out:
# array([[ 401842.99728318],
#        [1221634.46661472],
#        [ 855665.15016651],
#        ...,
#        [ 349097.43749828],
#        [ 413309.39110339],
#        [ 571736.83119389]])

# %%
lmr.predict(np.array([[3000,3,1.5]]))
# Out:
# array([[794730.2724843]])

# %%
r2_square1 = r2_score(Y_test,y_Pred)

# %%
r2_square1
# Out:
# 0.49400531569204464

# %%
X_train.head()
# Out:
#        sqft_living  bathrooms  floors
# 14323         1560       1.75     1.0
# 10300          750       1.00     1.0
# 16151         1230       1.75     1.0
# 6086           860       1.00     1.0
# 4577          1090       1.00     1.5

# %%
plt.scatter(X_test['sqft_living'],Y_test, color='red')
plt.plot( X_test['sqft_living'], lm.predict(X_test),color='green')
plt.title("Prediction Chart")
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.show()

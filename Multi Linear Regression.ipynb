# %%
import pandas as pd

# %%
dataset = pd.read_excel('C:/Users/kobalaji/Desktop/LetsUpgrade AI-ML/Example Dataset.xlsx')

# %%
dataset.head()
# Out:
#   Name  Sales Gender Smoker
# 0    A   2775      F      N
# 1    B   2035      M      Y
# 2    C   1835      M      N
# 3    D   1124      F      Y
# 4    E   2505      M     PA

# %%
#dataset['Gender'] = dataset['Gender'].replace({'F':0,'M':1})

# %%
dataset
# Out:
#    Name  Sales Gender Smoker
# 0     A   2775      F      N
# 1     B   2035      M      Y
# 2     C   1835      M      N
# 3     D   1124      F      Y
# 4     E   2505      M     PA
# 5     F   1808      F      N
# 6     G   2626      M      Y
# 7     H   2110      F     PA
# 8     I   1193      M      Y
# 9     J   2544      M      Y
# 10    K   2208      F      Y
# 11    L   2105      M      N

# %%
from  sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
dataset2 = dataset

# %%
dataset2['Gender'] = label_encoder.fit_transform(dataset['Gender'])

# %%
dataset2
# Out:
#    Name  Sales  Gender Smoker
# 0     A   2775       0      N
# 1     B   2035       1      Y
# 2     C   1835       1      N
# 3     D   1124       0      Y
# 4     E   2505       1     PA
# 5     F   1808       0      N
# 6     G   2626       1      Y
# 7     H   2110       0     PA
# 8     I   1193       1      Y
# 9     J   2544       1      Y
# 10    K   2208       0      Y
# 11    L   2105       1      N

# %%
dataset2['Smoker'] = label_encoder.fit_transform(dataset['Smoker'])

# %%
dataset2
# Out:
#    Name  Sales  Gender  Smoker
# 0     A   2775       0       0
# 1     B   2035       1       2
# 2     C   1835       1       0
# 3     D   1124       0       2
# 4     E   2505       1       1
# 5     F   1808       0       0
# 6     G   2626       1       2
# 7     H   2110       0       1
# 8     I   1193       1       2
# 9     J   2544       1       2
# 10    K   2208       0       2
# 11    L   2105       1       0

# %%
import seaborn as sns
g = sns.FacetGrid(dataset, col = "Gender", row= "Smoker")
g.map(sns.boxplot, "Sales")
# Out:
# c:\users\kobalaji\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dataset2.head()
# Out:
#   Name  Sales  Gender  Smoker
# 0    A   2775       0       0
# 1    B   2035       1       2
# 2    C   1835       1       0
# 3    D   1124       0       2
# 4    E   2505       1       1

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
# Name      12 non-null object
# Sales     12 non-null int64
# Gender    12 non-null int32
# Smoker    12 non-null int32
# dtypes: int32(2), int64(1), object(1)
# memory usage: 304.0+ bytes

# %%
dataset2.head()
# Out:
#   Name  Sales  Gender  Smoker
# 0    A   2775       0       0
# 1    B   2035       1       2
# 2    C   1835       1       0
# 3    D   1124       0       2
# 4    E   2505       1       1

# %%
dataset2 =dataset2.iloc[:,1:4]
dataset2
# Out:
#     Sales  Gender  Smoker
# 0    2775       0       0
# 1    2035       1       2
# 2    1835       1       0
# 3    1124       0       2
# 4    2505       1       1
# 5    1808       0       0
# 6    2626       1       2
# 7    2110       0       1
# 8    1193       1       2
# 9    2544       1       2
# 10   2208       0       2
# 11   2105       1       0

# %%
dataset2['Gender'] = dataset2['Gender'].astype('category')
dataset2['Smoker'] = dataset2['Smoker'].astype('category')

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
# Sales     12 non-null int64
# Gender    12 non-null category
# Smoker    12 non-null category
# dtypes: category(2), int64(1)
# memory usage: 352.0 bytes

# %%
dataset2 = pd.get_dummies(dataset2,drop_first=True)

# %%
dataset2.columns
# Out:
# Index(['Sales', 'Gender_1', 'Smoker_1', 'Smoker_2'], dtype='object')

# %%
dataset2.size
# Out:
# 48

# %%
dataset2.shape[0]
# Out:
# 12

# %%
dataset2
# Out:
#     Sales  Gender_1  Smoker_1  Smoker_2
# 0    2775         0         0         0
# 1    2035         1         0         1
# 2    1835         1         0         0
# 3    1124         0         0         1
# 4    2505         1         1         0
# 5    1808         0         0         0
# 6    2626         1         0         1
# 7    2110         0         1         0
# 8    1193         1         0         1
# 9    2544         1         0         1
# 10   2208         0         0         1
# 11   2105         1         0         0
